# %%
import pandas as pd

# %%
df=pd.read_csv(r"https://docs.google.com/spreadsheets/d/e/2PACX-1vSPVJIoDhupNyUpYD65FSHt6kMmF_KaxE2RD6CV1FOMP4vVw7WfKQMqpqo0ieD9vhMAmYP1NpBmw0od/pub?gid=658985149&single=true&output=csv")
df
# Out:
#          Back Table 1. Human Development Index and its components  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                              NaN         NaN                       NaN
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#          Back Table 1. Human Development Index and its components  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                              NaN         NaN                       NaN
# ...

# %%
df.drop(columns="Unnamed: 3")
# Out:
#          Back Table 1. Human Development Index and its components  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2                Unnamed: 4 Unnamed: 5  \
# 0                              NaN                       NaN        NaN
# ...

# %%
df
# Out:
#          Back Table 1. Human Development Index and its components  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2                Unnamed: 4  \
# 0                              NaN                       NaN
# ...

# %%
df["Unnamed: 2"]=df["Unnamed: 2"].str.lstrip("/")
df["Unnamed: 2"]=df["Unnamed: 2"].str.lstrip("...")
df["Unnamed: 2"]=df["Unnamed: 2"].str.rstrip("_")

# %%
df["Unnamed: 12"]=df["Unnamed: 12"].str.lstrip("-")

# %%
df = df.drop(3)

# %%
df = df.drop(1)

# %%
df = df.drop(4)
df = df.drop(6)

# %%
df = df.drop(df.index[231:274])

# %%
df
# Out:
#     Back Table 1. Human Development Index and its components Unnamed: 2  \
# 7      1                                        Switzerland         962
# 8      2                                             Norway         961
# 9      3                                            Iceland         959
# 10     4                             Hong Kong, China (SAR)         952
# 11     5                                          Australia         951
# ..   ...                                                ...         ...
# 241  NaN          k. Estimated using the PPP rate of Spain.         NaN
# 242  NaN              l. Based on cross-country regression.         NaN
# 243  NaN  m. Updated by HDRO based on data from UNESCO I...         NaN
# 244  NaN  n. Updated by HDRO based on data from Barro an...         NaN
# 245  NaN  o. Updated by HDRO based on data from CEDLAS a...         NaN
#
#     Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14
# ...

# %%
df = df.drop(231)
df = df.drop(232)
df = df.drop(233)
df = df.drop(234)
df = df.drop(235)
df = df.drop(236)
df = df.drop(237)
df = df.drop(238)
df = df.drop(239)
df = df.drop(240)
df = df.drop(241)
df = df.drop(242)
df = df.drop(243)
df = df.drop(244)

df
# Out:
#     Back Table 1. Human Development Index and its components Unnamed: 2  \
# 7      1                                        Switzerland         962
# 8      2                                             Norway         961
# 9      3                                            Iceland         959
# 10     4                             Hong Kong, China (SAR)         952
# 11     5                                          Australia         951
# ..   ...                                                ...         ...
# 221  NaN                                 Sub-Saharan Africa         547
# 223  NaN                          Least developed countries         540
# 224  NaN                     Small island developing states         730
# 226  NaN  Organisation for Economic Co-operation and Dev...         899
# 228  NaN                                              World         732
#
#     Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14
# ...

# %%
df = df.rename(columns={'Back': 'HDI rank', 'Table 1. Human Development Index and its components': 'Country', 'Unnamed: 2': 'Human Development Index (HDI)','Unnamed: 4': 'Life expectancy at birth','Unnamed: 6': 'Expected years of schooling','Unnamed: 8': 'Mean years of schooling','Unnamed: 10': 'Gross national income (GNI) per capita','Unnamed: 12': 'GNI per capita rank minus HDI rank','Unnamed: 14': 'HDI rank 2020'})

# %%
df
# Out:
#     HDI rank                                            Country  \
# 7          1                                        Switzerland
# 8          2                                             Norway
# 9          3                                            Iceland
# 10         4                             Hong Kong, China (SAR)
# 11         5                                          Australia
# ..       ...                                                ...
# 221      NaN                                 Sub-Saharan Africa
# 223      NaN                          Least developed countries
# 224      NaN                     Small island developing states
# 226      NaN  Organisation for Economic Co-operation and Dev...
# 228      NaN                                              World
#
#     Human Development Index (HDI) Life expectancy at birth  \
# 7                             962                     84.0
# 8                             961                     83.2
# ...

# %%
df["HDI rank"]=df["HDI rank"].str.replace("NaN","")

# %%
df.fillna("")
# Out:
#     HDI rank                                            Country  \
# 7          1                                        Switzerland
# 8          2                                             Norway
# 9          3                                            Iceland
# 10         4                             Hong Kong, China (SAR)
# 11         5                                          Australia
# ..       ...                                                ...
# 221                                          Sub-Saharan Africa
# 223                                   Least developed countries
# 224                              Small island developing states
# 226           Organisation for Economic Co-operation and Dev...
# 228                                                       World
#
#     Human Development Index (HDI) Life expectancy at birth  \
# 7                             962                     84.0
# 8                             961                     83.2
# ...

# %%
for x in df.index:
  if df.loc[x,"GNI per capita rank minus HDI rank"] == "—":
    df.drop(x,inplace=True)
    df

# %%
for x in df.index:
  if df.loc[x,"GNI per capita rank minus HDI rank"] == "..":
    df.drop(x,inplace=True)
    df

# %%
for x in df.index:
  if df.loc[x,"GNI per capita rank minus HDI rank"] == "OTHER COUNTRIES OR TERRITORIES":
    df.drop(x,inplace=True)
    df

# %%
df = df.drop(194)
df = df.drop(195)
df = df.drop(196)

# %%
df = df.drop(191)
df = df.drop(192)
df = df.drop(193)

# %%
df.reset_index(drop=True)
# Out:
#     HDI rank                         Country Human Development Index (HDI)  \
# 0          1                     Switzerland                           962
# 1          2                          Norway                           961
# 2          3                         Iceland                           959
# 3          4          Hong Kong, China (SAR)                           952
# 4          5                       Australia                           951
# ..       ...                             ...                           ...
# 186      190                            Chad                           394
# 187      191                     South Sudan                           385
# 188      NaN  OTHER COUNTRIES OR TERRITORIES                           NaN
# 189      NaN        Human development groups                           NaN
# 190      NaN                         Regions                           NaN
#
#     Life expectancy at birth Expected years of schooling  \
# ...
